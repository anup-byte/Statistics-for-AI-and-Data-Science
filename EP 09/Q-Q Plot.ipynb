# %%
# Q-Q Plot
import numpy as np
import pylab
import scipy.stats as stats

# N(0,1)
std_normal = np.random.normal(loc = 0, scale = 1, size = 1000)

# 0 to 100th percentiles of std-normal

for i in range(0, 101):
    print(i, np.percentile(std_normal, i))
# Out:
# 0 -3.2426408259011184
# 1 -2.328557115617551
# 2 -2.0853601401361366
# 3 -1.8797371751205139
# 4 -1.7526927639500463
# 5 -1.6660206891798852
# 6 -1.6045199405529913
# 7 -1.5663287011504479
# 8 -1.492349970230149
# 9 -1.3915297381106302
# 10 -1.3263419360822628
# 11 -1.2770132938820324
# 12 -1.1972036380689572
# 13 -1.1572876029838002
# 14 -1.121411340449683
# 15 -1.0619518983643352
# 16 -0.9993623405374483
# 17 -0.9647229902998614
# 18 -0.9223643571542339
# 19 -0.9023988481648031
# 20 -0.8469475965199095
# 21 -0.8097429279503007
# 22 -0.7768660040724793
# 23 -0.7529254600407411
# 24 -0.7304820696070407
# 25 -0.6912099191591362
# 26 -0.6590277300152566
# 27 -0.6287723864772272
# 28 -0.5922455817978266
# 29 -0.5516392635382337
# 30 -0.5168904958708371
# 31 -0.4867302798281875
# 32 -0.46734950963760447
# 33 -0.42622786544272034
# 34 -0.40488367147224735
# 35 -0.3849240138053747
# 36 -0.3433568157698795
# 37 -0.3068274954460729
# 38 -0.2670139984797128
# 39 -0.248269076043965
# 40 -0.23041704201293073
# 41 -0.19949279992545374
# 42 -0.16614906815333738
# 43 -0.1442984423437888
# 44 -0.12182509036087748
# 45 -0.09035027407571826
# 46 -0.0688702433005073
# 47 -0.05348196942263473
# 48 -0.03872805314313436
# 49 -0.018345505876502247
# 50 0.004158402025997227
# 51 0.018116564161162984
# 52 0.04667948785064044
# 53 0.07021001978809241
# 54 0.10435188539843021
# 55 0.12719712262268418
# 56 0.1559648763232136
# 57 0.19403595716734567
# 58 0.22065031286391185
# 59 0.2553027836132984
# 60 0.2731439243851349
# 61 0.28909000826295034
# 62 0.3370639717109239
# 63 0.3607611228266214
# 64 0.3756061724981026
# 65 0.40844684808560744
# 66 0.43406960816993906
# 67 0.4611376489732901
# 68 0.4810580732297247
# 69 0.5199251181664576
# 70 0.5433020429057608
# 71 0.5713189843748642
# 72 0.6061007380821581
# 73 0.6389938663392621
# 74 0.6644084150484325
# 75 0.6978800096524396
# 76 0.7253378099140402
# 77 0.743891354367786
# 78 0.7697494001005163
# 79 0.8154804382713133
# 80 0.8403099230226895
# 81 0.8742310364093454
# 82 0.8987988825355099
# 83 0.9498606724736073
# 84 1.0239674568125978
# 85 1.0603855180333766
# 86 1.1006515009388993
# 87 1.1425208009186398
# 88 1.2118209140667888
# 89 1.2597139973736349
# 90 1.33363375510525
# 91 1.3910683638511174
# 92 1.4381950390332603
# 93 1.507310049346394
# 94 1.5783297787480295
# 95 1.6675829918493554
# 96 1.7574530592149589
# 97 1.9048107428205445
# 98 2.0090356275113552
# 99 2.240830617517261
# 100 2.96821290818897

# %%
# generate 100 samples from N(20, 5)

measurements = np.random.normal(loc = 20, scale = 5, size = 50000)

# try size = 50000

stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
# generate 100 samples from N(20, 5)

measurements = np.random.uniform(low = -1, high = 1, size = 10000)

# try size = 10000

stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()
